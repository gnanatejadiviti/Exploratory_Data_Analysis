# %% [markdown]
# **Reading the CSV file**

# %% [markdown]
# - Packages required:

# %%
a = 20
b = 300
a*b
# Out:
# 6000

# %%
import pandas as pd                 # Dataframe operations
import numpy as np                  # Math operations
import matplotlib.pyplot as plt     # Diagrams / plots
import seaborn as sns               # Diagrams / plots

# %%
# Data set name : Visadataset
# read csv file : Comma separated value
# extension : .csv
# you can read this file using pandas

# read excel file
# extension : .xlsx

# %%
# Path
path = r"C:\Users\DELL\DS COURSE NARESH IT\python files\Visadataset - Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path = r"C:\Users\DELL\DS COURSE NARESH IT\python files\bank - bank.csv"
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# If the data is not aligned in proper datasets, Use separater 
pd.read_csv(path,sep = ';')

# %% [markdown]
# #### Create dataframes unsing List

# %%
name = ['Ramesh','Suresh','Sathish']
age = [30,35,40]
name,age
# Out:
# (['Ramesh', 'Suresh', 'Sathish'], [30, 35, 40])

# %% [markdown]
# **Step-1**\
# $Create$ $dataframe$

# %%
data = (zip(name,age))
data

# %% [markdown]
# **Step-2**\
# $Providing$ $the$ $columns$ $and$ $index$

# %%
df = pd.DataFrame(data,columns=['Name','Age'],index= ['A','B','C'])
df
# Out:
#       Name  Age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %% [markdown]
# **Step-3**\
# $Add$ $new$ $column$
# - If you want to add a new column
# - df['new_column_name']
# - You need to have a list which is having some elements
# - That elements need to equal to number of rows

# %%
city_names = ['Hyderabad','Mumbai','Chennai']
df['City'] = city_names
df
# Out:
#       Name  Age       City
# A   Ramesh   30  Hyderabad
# B   Suresh   35     Mumbai
# C  Sathish   40    Chennai

# %% [markdown]
# **Step-4**\
# $Updating$ $the$ $existing$ $column$

# %%
df['Name']=['Teja','Gnana','Ashish']
df
# Out:
#      Name  Age       City
# A    Teja   30  Hyderabad
# B   Gnana   35     Mumbai
# C  Ashish   40    Chennai

# %% [markdown]
# **Step-5**\
# $Drop$ $the$ $column$
# - In order to drop the column
# - We need to use drop method
# - It takes 3 parameters
#      - Drop column or row
#      - mention the coulmn name
#      - axis
#           - axis = 1 reference as column
#           - axis = 0 reference as row
#      - you want to create a new dataframe or
#      - you want to overwrite the existing dataframe
#           - inplace = True

# %%
df.drop('C',
       axis = 0,
       inplace=True)
df
# Out:
#     Name  Age       City
# A   Teja   30  Hyderabad
# B  Gnana   35     Mumbai

# %%
df.drop('Name',
       axis = 1,
       inplace= True)
df
# Out:
#    Age       City
# A   30  Hyderabad
# B   35     Mumbai

# %%
name = ['Ramesh','Suresh','Sathish']
age = [30,35,40]

data = (zip(name,age))

df = pd.DataFrame(data,columns=['Name','Age'],index= ['A','B','C'])

city_names = ['Hyderabad','Mumbai','Chennai']
df['City'] = city_names

df.drop('C',
       axis = 0,
       inplace = True)
df
# Out:
#      Name  Age       City
# A  Ramesh   30  Hyderabad
# B  Suresh   35     Mumbai

# %% [markdown]
# **Step-6**\
# $Saving$ $the$ $data$ $frame$

# %%
df.to_csv("Dataframe1.csv")

# %%
# Reading the Dataframe1

# %%
pd.read_csv(r"C:\Users\DELL\DS COURSE NARESH IT\DS COURSE NARESH IT\EDA\Dataframe1.csv")
# Out:
#   Unnamed: 0    Name  Age       City
# 0          A  Ramesh   30  Hyderabad
# 1          B  Suresh   35     Mumbai

# %%
# To avoid the above problem that is Unnamed index:

df.to_csv("Dataframe2.csv",index=False)

# %%
# Reading Dataframe2

# %%
pd.read_csv(r"C:\Users\DELL\DS COURSE NARESH IT\DS COURSE NARESH IT\EDA\Dataframe2.csv")
# Out:
#      Name  Age       City
# 0  Ramesh   30  Hyderabad
# 1  Suresh   35     Mumbai

# %% [markdown]
# #### Creating dataframes using Dictionary

# %%
import pandas as pd
d1 = {"Comapany":['Apple','MI','Realme','Moto'],
     "Price":[50000,20000,18000,25000]}

pd.DataFrame(d1)

df = pd.DataFrame(d1,index=['A','B','C','D'])

names = ['Sam','Jam','Kam','Lam']
df['Names'] = names

df.drop('Price',
       axis=1,
       inplace=True)

df.to_csv(r"C:\Users\DELL\DS COURSE NARESH IT\DS COURSE NARESH IT\EDA\Dataframe5.csv",index = False)

pd.read_csv(r"C:\Users\DELL\DS COURSE NARESH IT\DS COURSE NARESH IT\EDA\Dataframe5.csv")
# Out:
#   Comapany Names
# 0    Apple   Sam
# 1       MI   Jam
# 2   Realme   Kam
# 3     Moto   Lam
