# %% [markdown]
# #### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read the data

# %%
path = r'C:\Users\DELL\DS COURSE NARESH IT\python files\Visadataset - Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# To get numerical data
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# - In the numerical analysis
# - Mean, median , standard deviation, Count, 25p, 50p are used

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %% [markdown]
# $Count$

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
wage_count=visa_df['prevailing_wage'].count()
wage_count
# Out:
# 25480

# %% [markdown]
# $Mean$

# %%
wage_mean=round(visa_df['prevailing_wage'].mean(),2) # Using pandas
wage_mean
# Out:
# 74455.81

# %%
np.mean(visa_df['prevailing_wage']) # Using numpy
# Out:
# 74455.81459209183

# %% [markdown]
# $Median$

# %%
wage_median=round(visa_df['prevailing_wage'].median(),2)
wage_median
# Out:
# 70308.21

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %% [markdown]
# $Max$

# %%
wage_max=round(visa_df['prevailing_wage'].max(),2)
wage_max
# Out:
# 319210.27

# %%
np.max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %% [markdown]
# $Min$

# %%
wage_min=round(visa_df['prevailing_wage'].min(),2)
wage_min
# Out:
# 2.14

# %%
np.min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %% [markdown]
# $Standard$ $Deviation$

# %%
wage_std=round(visa_df['prevailing_wage'].std(),2)
wage_std
# Out:
# 52815.94

# %%
np.std(visa_df['prevailing_wage'])
# Out:
# 52814.90589711402

# %%
l = [wage_count,wage_mean,wage_median,wage_max,wage_min,wage_std]
cols = ['Prevailing Wage']
index = ['Count','Mean','Median','Max','Min','Std']
pd.DataFrame(l,columns=cols,index=index)
# Out:
#         Prevailing Wage
# Count          25480.00
# Mean           74455.81
# Median         70308.21
# Max           319210.27
# Min                2.14
# Std            52815.94

# %% [markdown]
# $Percentile$-$Quantile$

# %% [markdown]
# - Pencentile and Quantile are available in numpy
# - np.percentile()
#     - column name
#     - percentile value btw 0 to 100
# - np.quantile()
#     - column name
#     - 0 to 1
# - In quantile 0.25 means 25 in percentile

# %% [markdown]
# ## 25p

# %%
wage_25p=np.percentile(visa_df['prevailing_wage'],25) # Percentile
wage_25p
# Out:
# 34015.479999999996

# %%
np.quantile(visa_df['prevailing_wage'],0.25) # Quantile
# Out:
# 34015.479999999996

# %% [markdown]
# **Means 25% of total data i.e, 6370, these members have wages less than 34015.47**

# %%
con = visa_df['prevailing_wage']<34015.479999999996
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## 50p

# %%
wage_50p=np.percentile(visa_df['prevailing_wage'],50)
wage_50p
# Out:
# 70308.20999999999

# %% [markdown]
# **Means 50% of total data i.e, 12740, these members have wages less than 70308.20999999999**

# %%
con = visa_df['prevailing_wage']<70308.20999999999
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## 75p

# %%
wage_75p=np.percentile(visa_df['prevailing_wage'],75)
wage_75p
# Out:
# 107735.51250000001

# %%
con=visa_df['prevailing_wage']<wage_75p
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
l = [wage_count,wage_mean,wage_median,wage_max,wage_min,wage_std,wage_25p,wage_50p,wage_75p]
cols = ['Prevailing Wage']
index = ['Count','Mean','Median','Max','Min','Std','25%','50%','75%']
pd.DataFrame(l,columns=cols,index=index)
# Out:
#         Prevailing Wage
# Count        25480.0000
# Mean         74455.8100
# Median       70308.2100
# Max         319210.2700
# Min              2.1400
# Std          52815.9400
# 25%          34015.4800
# 50%          70308.2100
# 75%         107735.5125

# %%
visa_df.describe() # Because there are 3 numerical columns
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
# All together
cols=visa_df.select_dtypes(exclude='object').columns
l=[]
for i in cols:
    count=round(visa_df[i].count(),2)
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    max_=visa_df[i].max()
    min_=visa_df[i].min()
    std=round(visa_df[i].std(),2)
    p_25=round(np.percentile(visa_df[i],25),2)
    p_50=round(np.percentile(visa_df[i],50),2)
    p_75=round(np.percentile(visa_df[i],75),2)
    
    l.append([count,mean,median,max_,min_,std,p_25,p_50,p_75])

index=['count','mean','median','max_','min_','std','25%','50%','75%']
pd.DataFrame(zip(l[0],l[1],l[2]),columns=cols,index=index)
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# mean            5667.04      1979.41       74455.8100
# median          2109.00      1997.00       70308.2100
# max_          602069.00      2016.00      319210.2700
# min_             -26.00      1800.00           2.1367
# std            22877.93        42.37       52815.9400
# 25%             1022.00      1976.00       34015.4800
# 50%             2109.00      1997.00       70308.2100
# 75%             3504.00      2005.00      107735.5100

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = r'C:\Users\DELL\DS COURSE NARESH IT\python files\Visadataset - Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## Histogram

# %%
plt.hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
f1,i1,n1=plt.hist(visa_df['prevailing_wage'],bins=100)

# %%
len(f1),len(i1),len(n1)
# Out:
# (100, 101, 100)

# %%
f,i,n=plt.hist(visa_df['prevailing_wage'],
        bins=40)

# %%
len(f),len(i),len(n)
# Out:
# (40, 41, 40)

# %%
f
# Out:
# array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#        1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#         509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#          79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#           7.,    3.,    6.,    5.])

# %%
i
# Out:
# array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#        3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#        6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#        9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#        1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#        1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#        1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#        2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#        2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#        2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#        3.19210270e+05])

# %%
n
# Out:
# <BarContainer object of 40 artists>

# %%
# Btw 2.13670000e+00 and 7.98234003e+03 intervals
# We have 2992 frequencies/ observations

# %%
lowest_interval = 2.13670000e+00
upper_interval = 7.98234003e+03

condition1 = visa_df['prevailing_wage']>=lowest_interval
contition2 = visa_df['prevailing_wage']<upper_interval

visa_df[condition1 & contition2]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 36        EZYV37         Europe           High School                  Y
# 54        EZYV55           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25450  EZYV25451           Asia            Bachelor's                  N
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
def frequency(l,u):
    c1=visa_df['prevailing_wage']>=l
    c2=visa_df['prevailing_wage']<u
    c=c1&c2
    print(len(visa_df[c]))
frequency( 3.11230067e+05,
       3.19210270e+05)
# Out:
# 4

# %% [markdown]
# ## Task-1
# #### Create a dataframe

# %%
lower       upper        frequency
2.136        7.98          2992

# %%
fre,inter,n=plt.hist(visa_df['prevailing_wage'],
        bins=40)

# %%
frequency = []
index= []
for i in range(len(n)):
    con1 = visa_df['prevailing_wage']>=inter[i]
    con2 = visa_df['prevailing_wage']<=inter[1:][i]
    c = con1 & con2
    frequency.append(len(visa_df[c]))
    index.append(i+1)

# %%
df = pd.DataFrame(zip(inter,inter[1:],frequency),columns=['Lower','Upper','Frequency'],index=index)
df
# Out:
#             Lower          Upper  Frequency
# 1        2.136700    7982.340033       2992
# 2     7982.340033   15962.543365        871
# 3    15962.543365   23942.746698       1005
# 4    23942.746698   31922.950030       1170
# 5    31922.950030   39903.153363       1242
# 6    39903.153363   47883.356695       1434
# 7    47883.356695   55863.560028       1385
# 8    55863.560028   63843.763360       1443
# 9    63843.763360   71823.966693       1444
# 10   71823.966693   79804.170025       1445
# 11   79804.170025   87784.373358       1457
# 12   87784.373358   95764.576690       1335
# 13   95764.576690  103744.780023       1268
# 14  103744.780023  111724.983355       1217
# 15  111724.983355  119705.186688       1088
# 16  119705.186688  127685.390020        978
# 17  127685.390020  135665.593353        807
# 18  135665.593353  143645.796685        645
# 19  143645.796685  151626.000018        509
# 20  151626.000018  159606.203350        373
# ...

# %% [markdown]
# ## Task-2
# #### How to plot Histogram

# %%
sns.histplot(visa_df['prevailing_wage'],bins=40)
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Count'>

# %%
sns.histplot(visa_df['prevailing_wage'],bins=40,stat='frequency')
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Frequency'>

# %% [markdown]
# ## Boxplot
# - **Boxplot is used to identify outliers**
# - **In box plot we have**
#     - **Q1**: 25p value
#     - **Q2**: 50p value
#     - **Q3**: 75p value
#     - **IQR**: Q3-Q1
#     - Mild outliers Q1-1.5xIQR and Q3+1.5xIQR
#     - Huge outliers Q1-3xIQR and Q3+3xIQR

# %%
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.show()

# Black dots are outliers
# Orange line is median
# vert: False (Horizontal), vert: True (Vertical,default)
